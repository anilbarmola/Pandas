# %%
import pandas as pd
import matplotlib as plt

# %%
df=pd.read_csv("studentsdata.csv")

# %%
#convert your data into pickle format it is secure and can not read easly
df2=df.to_pickle("studentdata_to_pickle_format")

# %%
df.head()
# Out:
#   Gender    Age Education Level Institution Type IT Student Location  \
# 0    Boy  21-25      University   Non Government         No      Yes
# 1   Girl  21-25      University   Non Government         No      Yes
# 2   Girl  16-20         College       Government         No      Yes
# 3   Girl  11-15          School   Non Government         No      Yes
# 4   Girl  16-20          School   Non Government         No      Yes
#
#   Load-shedding Financial Condition Internet Type Network Type Class Duration  \
# 0           Low                 Mid          Wifi           4G            3-6
# 1          High                 Mid   Mobile Data           4G            1-3
# 2           Low                 Mid          Wifi           4G            1-3
# 3           Low                 Mid   Mobile Data           4G            1-3
# 4           Low                Poor   Mobile Data           3G              0
#
#   Self Lms  Device Adaptivity Level
# 0       No     Tab         Moderate
# ...

# %%
df.dtypes
# Out:
# Gender                 object
# Age                    object
# Education Level        object
# Institution Type       object
# IT Student             object
# Location               object
# Load-shedding          object
# Financial Condition    object
# Internet Type          object
# Network Type           object
# Class Duration         object
# Self Lms               object
# Device                 object
# Adaptivity Level       object
# dtype: object

# %%
df.describe()
# Out:
#        Gender    Age Education Level Institution Type IT Student Location  \
# count    1205   1205            1205             1205       1205     1205
# unique      2      6               3                2          2        2
# top       Boy  21-25          School   Non Government         No      Yes
# freq      663    374             530              823        901      935
#
#        Load-shedding Financial Condition Internet Type Network Type  \
# count           1205                1205          1205         1205
# unique             2                   3             2            3
# top              Low                 Mid   Mobile Data           4G
# freq            1004                 878           695          775
#
#        Class Duration Self Lms  Device Adaptivity Level
# count            1205     1205    1205             1205
# unique              3        2       3                3
# top               1-3       No  Mobile         Moderate
# ...

# %%
import requests

# %%
df1=pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
df1.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df1.dtypes
# Out:
# url                                      object
# repository_url                           object
# labels_url                               object
# comments_url                             object
# events_url                               object
# html_url                                 object
# id                                        int64
# node_id                                  object
# number                                    int64
# title                                    object
# user                                     object
# labels                                   object
# state                                    object
# locked                                     bool
# assignee                                 object
# assignees                                object
# milestone                                object
# comments                                  int64
# created_at                  datetime64[ns, UTC]
# updated_at                  datetime64[ns, UTC]
# ...

# %%
df1.describe()
# Out:
#                  id       number   comments  active_lock_reason  \
# count  3.000000e+01     30.00000  30.000000                 0.0
# mean   1.247740e+09  47113.50000   1.600000                 NaN
# std    1.508067e+06     11.80225   1.792706                 NaN
# min    1.244734e+09  47094.00000   0.000000                 NaN
# 25%    1.246742e+09  47103.50000   0.000000                 NaN
# 50%    1.247799e+09  47112.50000   1.000000                 NaN
# 75%    1.248830e+09  47123.25000   2.000000                 NaN
# max    1.250311e+09  47134.00000   7.000000                 NaN
#
#        performed_via_github_app  state_reason      draft
# count                       0.0           0.0  15.000000
# mean                        NaN           NaN   0.066667
# std                         NaN           NaN   0.258199
# min                         NaN           NaN   0.000000
# 25%                         NaN           NaN   0.000000
# ...

# %%
y=df1.iloc(1)
for i in y:
    print(i)
# Out:
# 0     https://api.github.com/repos/pandas-dev/pandas...
# 1     https://api.github.com/repos/pandas-dev/pandas...
# 2     https://api.github.com/repos/pandas-dev/pandas...
# 3     https://api.github.com/repos/pandas-dev/pandas...
# 4     https://api.github.com/repos/pandas-dev/pandas...
# 5     https://api.github.com/repos/pandas-dev/pandas...
# 6     https://api.github.com/repos/pandas-dev/pandas...
# 7     https://api.github.com/repos/pandas-dev/pandas...
# 8     https://api.github.com/repos/pandas-dev/pandas...
# 9     https://api.github.com/repos/pandas-dev/pandas...
# 10    https://api.github.com/repos/pandas-dev/pandas...
# 11    https://api.github.com/repos/pandas-dev/pandas...
# 12    https://api.github.com/repos/pandas-dev/pandas...
# 13    https://api.github.com/repos/pandas-dev/pandas...
# 14    https://api.github.com/repos/pandas-dev/pandas...
# 15    https://api.github.com/repos/pandas-dev/pandas...
# 16    https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df.iloc(1)
for i in df.iloc(1):
    print(i)
# Out:
# 0        Boy
# 1       Girl
# 2       Girl
# 3       Girl
# 4       Girl
#         ...
# 1200    Girl
# 1201    Girl
# 1202     Boy
# 1203    Girl
# 1204    Girl
# Name: Gender, Length: 1205, dtype: object
# 0       21-25
# 1       21-25
# 2       16-20
# 3       11-15
# 4       16-20
#         ...
# 1200    16-20
# 1201    16-20
# 1202    11-15
# 1203    16-20
# 1204    11-15
# Name: Age, Length: 1205, dtype: object
# 0       University
# 1       University
# 2          College
# 3           School
# 4           School
#            ...
# 1200       College
# 1201       College
# 1202        School
# 1203       College
# 1204        School
# Name: Education Level, Length: 1205, dtype: object
# 0       Non Government
# 1       Non Government
# 2           Government
# 3       Non Government
# 4       Non Government
#              ...
# 1200    Non Government
# 1201    Non Government
# 1202    Non Government
# 1203    Non Government
# 1204    Non Government
# ...
